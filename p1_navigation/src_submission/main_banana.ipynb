# %% [markdown]
# # Navigation
# ---
# This notebook is **the central file you want to use**. It contains
# - all the import statements and instructions to start the Unity ML-Agents environment
# - the calls to **train** the agent
# - the calls to **test** the agent
#
# ---
#
# This project is part of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np
import sys
import time  # to time the learning process
import torch
from collections import deque
from collections import Counter  # to offer statistics about the distribution in actions and rewards
import matplotlib.pyplot as plt
# %matplotlib inline
from pprint import pprint  #  “pretty-print” arbitrary Python data structures 

from dqn_agent_banana import Agent

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Banana.app"`
# - **Windows** (x86): `"path/to/Banana_Windows_x86/Banana.exe"`
# - **Windows** (x86_64): `"path/to/Banana_Windows_x86_64/Banana.exe"`
# - **Linux** (x86): `"path/to/Banana_Linux/Banana.x86"`
# - **Linux** (x86_64): `"path/to/Banana_Linux/Banana.x86_64"`
# - **Linux** (x86, headless): `"path/to/Banana_Linux_NoVis/Banana.x86"`
# - **Linux** (x86_64, headless): `"path/to/Banana_Linux_NoVis/Banana.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Banana.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Banana.app")
# ```

# %%
env = UnityEnvironment(file_name="C:/Users/simon.chauvin/Documents/Private GitHub/deep-reinforcement-learning/p1_navigation/Banana_Windows_x86_64/Banana.exe")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# [`README.md`](https://github.com/chauvinSimon/deep-reinforcement-learning/p1_navigation/README.md) describes the environment (_state space_, _action space_, _reward function_).
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', len(state))
print('States have type:', type(state))
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [1.         0.         0.         0.         0.84408134 0.
#  0.         1.         0.         0.0748472  0.         1.
#  0.         0.         0.25755    1.         0.         0.
#  0.         0.74177343 0.         1.         0.         0.
#  0.25854847 0.         0.         1.         0.         0.09355672
#  0.         1.         0.         0.         0.31969345 0.
#  0.        ]
# States have length: 37
# States have type: <class 'numpy.ndarray'>

# %% [markdown]
# Instanciate an Agent and decide whether you want to train or test it

# %%
agent = Agent(state_size=state_size, action_size=action_size, seed=0)
banana_training = True
banana_test = True

# %% [markdown]
# ### 3. Training
# When training the environment, we set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
def dqn(n_episodes=5000, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.935):
    """Deep Q-Learning function to train the Agent

    Params
    
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []  # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start  # initialize epsilon
    time_start = time.time()

    for i_episode in range(1, n_episodes + 1):
        # reset the environement for a new episode
        env_info = env.reset(train_mode=True)[brain_name]
        state = env_info.vector_observations[0]

        # reset metrics
        score = 0
        rewards = []
        actions = []
        changes_in_state = 0

        # run episodes
        for t in range(max_t):
            #  select an action for the current state
            action = int(agent.act(state, eps))
            
            # send the action to the environment
            env_info = env.step(action)[brain_name]
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]
            agent.step(state, action, reward, next_state, done)

            # monitor actions, states and rewards are not constant
            rewards.append(reward)
            actions.append(action)
            if not (next_state == state).all():
                changes_in_state = changes_in_state + 1
            
            state = next_state

            #  statistics
            score += reward                                # update the score
#             print("\r {} = i_episode\n {}, {}, {}".format(i_episode, action, reward, done),
#                   sep=' ', end='', flush=True)
            if done:                                       # exit loop if episode finished
                break
        
        # decay epsilon
        eps = max(eps_end, eps_decay * eps)
        
        # log
        scores_window.append(score)  # save most recent score
        scores.append(score)  # save most recent score        
        if i_episode % 10 == 0:
            print("\n --- Episode --- {}\n\t eps: {}\n\t score: {:.2f},\n\t rewards: {}, \n\t action: {}, \n\t changes_in_state: {}".format(
                i_episode, eps, score, Counter(rewards), Counter(actions), changes_in_state), sep=' ',
                end='\n', flush=True)
        if i_episode % 100 == 0:
            time_intermediate = time.time()
            print('\n --- Episode={} ---\n eps={}\n Average Score= {:.2f} \n duration={:.2f}'.format(
                i_episode, eps, np.mean(scores_window), time_intermediate - time_start))

            print("saving weights")
            torch.save(agent.q_network_local.state_dict(), 'checkpoint.pth')

            fig = plt.figure()
            ax = fig.add_subplot(111)
            plt.plot(np.arange(len(scores)), scores)
            plt.ylabel('Score')
            plt.xlabel('Episode #')
            plt.show()

        if np.mean(scores_window) >= 13.0:
            time_stop = time.time()
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}, duration={:.2f}'.format(
                i_episode - 100, np.mean(scores_window), time_stop - time_start))
            torch.save(agent.q_network_local.state_dict(), 'checkpoint.pth')
            break
    return scores

# %%
if banana_training:
    # If you want to further train an Agent, load the weights from file
    # agent.q_network_local.load_state_dict(torch.load('checkpoint.pth'))
    
    scores = dqn()
# Out:
#  --- Episode --- 10
# 	 eps: 0.5106415018454286
# 	 score: 1.00,
# 	 rewards: Counter({0.0: 299, 1.0: 1}),
# 	 action: Counter({0: 104, 3: 80, 2: 63, 1: 53}),
# 	 changes_in_state: 300
#
#  --- Episode --- 20
# 	 eps: 0.26075474340695476
# 	 score: 3.00,
# 	 rewards: Counter({0.0: 297, 1.0: 3}),
# 	 action: Counter({3: 84, 0: 82, 1: 69, 2: 65}),
# 	 changes_in_state: 300
#
#  --- Episode --- 30
# 	 eps: 0.13315219378664672
# 	 score: 6.00,
# 	 rewards: Counter({0.0: 290, 1.0: 8, -1.0: 2}),
# 	 action: Counter({0: 147, 1: 67, 3: 51, 2: 35}),
# 	 changes_in_state: 300
#
#  --- Episode --- 40
# 	 eps: 0.0679930362092268
# 	 score: 6.00,
# 	 rewards: Counter({0.0: 294, 1.0: 6}),
# 	 action: Counter({2: 108, 3: 100, 0: 80, 1: 12}),
# 	 changes_in_state: 300
#
#  --- Episode --- 50
# 	 eps: 0.03472006612491016
# 	 score: 12.00,
# 	 rewards: Counter({0.0: 286, 1.0: 13, -1.0: 1}),
# 	 action: Counter({0: 171, 3: 67, 2: 53, 1: 9}),
# 	 changes_in_state: 300
#
#  --- Episode --- 60
# 	 eps: 0.01772950671019671
# 	 score: 8.00,
# 	 rewards: Counter({0.0: 290, 1.0: 9, -1.0: 1}),
# 	 action: Counter({0: 142, 3: 80, 2: 66, 1: 12}),
# 	 changes_in_state: 300
#
#  --- Episode --- 70
# 	 eps: 0.01
# 	 score: 6.00,
# 	 rewards: Counter({0.0: 292, 1.0: 7, -1.0: 1}),
# 	 action: Counter({0: 226, 3: 48, 2: 24, 1: 2}),
# 	 changes_in_state: 234
#
#  --- Episode --- 80
# 	 eps: 0.01
# 	 score: 17.00,
# 	 rewards: Counter({0.0: 281, 1.0: 18, -1.0: 1}),
# 	 action: Counter({0: 228, 3: 43, 2: 28, 1: 1}),
# 	 changes_in_state: 300
#
#  --- Episode --- 90
# 	 eps: 0.01
# 	 score: 13.00,
# 	 rewards: Counter({0.0: 287, 1.0: 13}),
# 	 action: Counter({0: 186, 3: 76, 2: 27, 1: 11}),
# 	 changes_in_state: 300
#
#  --- Episode --- 100
# 	 eps: 0.01
# 	 score: 11.00,
# 	 rewards: Counter({0.0: 287, 1.0: 12, -1.0: 1}),
# 	 action: Counter({0: 170, 3: 65, 2: 49, 1: 16}),
# 	 changes_in_state: 300
#
#  --- Episode=100 ---
#  eps=0.01
#  Average Score= 7.24
#  duration=187.32
# saving weights
#  --- Episode --- 110
# 	 eps: 0.01
# 	 score: 10.00,
# 	 rewards: Counter({0.0: 288, 1.0: 11, -1.0: 1}),
# 	 action: Counter({0: 175, 3: 71, 2: 52, 1: 2}),
# 	 changes_in_state: 300
#
#  --- Episode --- 120
# 	 eps: 0.01
# 	 score: 11.00,
# 	 rewards: Counter({0.0: 289, 1.0: 11}),
# 	 action: Counter({0: 269, 2: 17, 3: 12, 1: 2}),
# 	 changes_in_state: 191
#
#  --- Episode --- 130
# 	 eps: 0.01
# 	 score: 10.00,
# 	 rewards: Counter({0.0: 290, 1.0: 10}),
# 	 action: Counter({0: 230, 2: 39, 3: 30, 1: 1}),
# 	 changes_in_state: 300
#
#  --- Episode --- 140
# 	 eps: 0.01
# 	 score: 14.00,
# 	 rewards: Counter({0.0: 286, 1.0: 14}),
# 	 action: Counter({0: 193, 2: 60, 3: 37, 1: 10}),
# 	 changes_in_state: 300
#
#  --- Episode --- 150
# 	 eps: 0.01
# 	 score: 16.00,
# 	 rewards: Counter({0.0: 284, 1.0: 16}),
# 	 action: Counter({0: 214, 2: 52, 3: 34}),
# 	 changes_in_state: 300
#
#  --- Episode --- 160
# 	 eps: 0.01
# 	 score: 15.00,
# 	 rewards: Counter({0.0: 283, 1.0: 16, -1.0: 1}),
# 	 action: Counter({0: 187, 2: 56, 3: 51, 1: 6}),
# 	 changes_in_state: 300
#
#  --- Episode --- 170
# 	 eps: 0.01
# 	 score: 15.00,
# 	 rewards: Counter({0.0: 285, 1.0: 15}),
# 	 action: Counter({0: 217, 3: 42, 2: 39, 1: 2}),
# 	 changes_in_state: 300
#
#  --- Episode --- 180
# 	 eps: 0.01
# 	 score: 10.00,
# 	 rewards: Counter({0.0: 290, 1.0: 10}),
# 	 action: Counter({0: 189, 2: 63, 3: 48}),
# 	 changes_in_state: 300
#
#  --- Episode --- 190
# 	 eps: 0.01
# 	 score: 16.00,
# 	 rewards: Counter({0.0: 284, 1.0: 16}),
# 	 action: Counter({0: 190, 3: 62, 2: 44, 1: 4}),
# 	 changes_in_state: 300
#
#  --- Episode --- 200
# 	 eps: 0.01
# 	 score: 18.00,
# 	 rewards: Counter({0.0: 282, 1.0: 18}),
# 	 action: Counter({0: 228, 2: 46, 3: 26}),
# 	 changes_in_state: 300
#
#  --- Episode=200 ---
#  eps=0.01
#  Average Score= 12.69
#  duration=377.86
# saving weights
#  --- Episode --- 210
# 	 eps: 0.01
# 	 score: 14.00,
# 	 rewards: Counter({0.0: 286, 1.0: 14}),
# 	 action: Counter({0: 227, 3: 37, 2: 34, 1: 2}),
# 	 changes_in_state: 300
#
#  --- Episode --- 220
# 	 eps: 0.01
# 	 score: 14.00,
# 	 rewards: Counter({0.0: 286, 1.0: 14}),
# 	 action: Counter({0: 236, 3: 34, 2: 24, 1: 6}),
# 	 changes_in_state: 300
#
# Environment solved in 123 episodes!	Average Score: 13.07, duration=423.04

# %% [markdown]
# Display final results

# %%
if banana_training:
    # print(scores)

    # plot the scores
    plt.rcParams["figure.figsize"] = [12, 9]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(len(scores)), scores)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.grid()
    plt.show()
    fig.savefig('rewards.svg', format='svg', dpi=1200)

# %% [markdown]
# Watch the agent after learning

# %% [markdown]
# ### 4. Testing
# Time to watch the agent's performance

# %%
if banana_test:
    # load the weights from file
    agent.q_network_local.load_state_dict(torch.load('checkpoint.pth'))

    env_info = env.reset(train_mode=False)[brain_name] # reset the environment
    state = env_info.vector_observations[0]            # get the current state
    score = 0                                          # initialize the score
    while True:
        action = int(agent.act(state))  # type(act) = numpy.int64 (but expected is <class 'int'>)
        env_info = env.step(action)[brain_name]        # send the action to the environment
        next_state = env_info.vector_observations[0]   # get the next state
        reward = env_info.rewards[0]                   # get the reward
        done = env_info.local_done[0]                  # see if episode has finished
        score += reward                                # update the score
        state = next_state                             # roll over the state to next time step
        print("\r {}, {}, {}.".format(action, reward, done), end="")
        sys.stdout.flush()
        if done:                                       # exit loop if episode finished
            break

    print("Score: {}".format(score))
# Out:
#  3, 0.0, True..Score: 21.0

# %% [markdown]
# Do not forget to close the environment at the end

# %%
env.close()
